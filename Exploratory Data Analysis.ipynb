# %% [markdown]
# # **By Saumya Awasthi**

# %% [markdown]
# **To Explore Business Analytics**

# %% [markdown]
# **Objective: To Perform Exploratory Data Analysis on the SampleSuperstore Dataset**

# %%
#Importing required libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#Import datset
import pandas as pd
data = pd.read_csv('/content/gdrive/My Drive/SampleSuperstore (2).csv')
data.head()
# Out:
#         Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0    Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1    Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2    Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3  Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4  Standard Class   Consumer  United States  ...        2     0.20    2.5164
#
# [5 rows x 13 columns]

# %%
data.shape
# Out:
# (9994, 13)

# %%
data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# Most of the features are of string type

# %% [markdown]
# **Let's look for missing values**

# %%
data.isna().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# Dataset doesn't has null values

# %%
data.describe(include='all')
# Out:
#              Ship Mode   Segment  ...     Discount       Profit
# count             9994      9994  ...  9994.000000  9994.000000
# unique               4         3  ...          NaN          NaN
# top     Standard Class  Consumer  ...          NaN          NaN
# freq              5968      5191  ...          NaN          NaN
# mean               NaN       NaN  ...     0.156203    28.656896
# std                NaN       NaN  ...     0.206452   234.260108
# min                NaN       NaN  ...     0.000000 -6599.978000
# 25%                NaN       NaN  ...     0.000000     1.728750
# 50%                NaN       NaN  ...     0.200000     8.666500
# 75%                NaN       NaN  ...     0.200000    29.364000
# max                NaN       NaN  ...     0.800000  8399.976000
#
# [11 rows x 13 columns]

# %%
data.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
city = data['City'].unique()
city
# Out:
# array(['Henderson', 'Los Angeles', 'Fort Lauderdale', 'Concord',
#        'Seattle', 'Fort Worth', 'Madison', 'West Jordan', 'San Francisco',
#        'Fremont', 'Philadelphia', 'Orem', 'Houston', 'Richardson',
#        'Naperville', 'Melbourne', 'Eagan', 'Westland', 'Dover',
#        'New Albany', 'New York City', 'Troy', 'Chicago', 'Gilbert',
#        'Springfield', 'Jackson', 'Memphis', 'Decatur', 'Durham',
#        'Columbia', 'Rochester', 'Minneapolis', 'Portland', 'Saint Paul',
#        'Aurora', 'Charlotte', 'Orland Park', 'Urbandale', 'Columbus',
#        'Bristol', 'Wilmington', 'Bloomington', 'Phoenix', 'Roseville',
#        'Independence', 'Pasadena', 'Newark', 'Franklin', 'Scottsdale',
#        'San Jose', 'Edmond', 'Carlsbad', 'San Antonio', 'Monroe',
#        'Fairfield', 'Grand Prairie', 'Redlands', 'Hamilton', 'Westfield',
#        'Akron', 'Denver', 'Dallas', 'Whittier', 'Saginaw', 'Medina',
#        'Dublin', 'Detroit', 'Tampa', 'Santa Clara', 'Lakeville',
# ...

# %%
#Look for duplicate values
data.duplicated().sum()
# Out:
# 17

# %%
# drop duplicate values
data.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of            Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0       Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1       Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2       Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3     Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4     Standard Class   Consumer  United States  ...        2     0.20    2.5164
# ...              ...        ...            ...  ...      ...      ...       ...
# 9989    Second Class   Consumer  United States  ...        3     0.20    4.1028
# 9990  Standard Class   Consumer  United States  ...        2     0.00   15.6332
# 9991  Standard Class   Consumer  United States  ...        2     0.20   19.3932
# 9992  Standard Class   Consumer  United States  ...        4     0.00   13.3200
# ...

# %%
#Now the shape of data is:
data.shape
# Out:
# (9994, 13)

# %%
sns.pairplot(data)

# %%
correlation = data.corr()
correlation
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
plt.figure(figsize=(14,6))
sns.heatmap(correlation, annot=True)

# %% [markdown]
# By heatmap we can conclude that: Sales and Profit , Sales and Quantity are moderately correlated

# %%
sns.displot(data['Sales'], color= 'red')
plt.xlim(-100,5000)
plt.show()

# %%
sns.distplot(data['Quantity'], color= 'red')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **It can be concluded from the graph that most of the people prefer buying two or four items by quantity**

# %%
sns.distplot(data['Profit'],color='r')
plt.xlim(-5000,5000)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# We know that there is only one unique value in country i.e., USA.So stores are located in USA only

# %%
#Count the number of states

st = data['State'].value_counts()
st
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Virginia                 224
# Arizona                  224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Missouri                  66
# Oklahoma                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %% [markdown]
# California has the largest number of sales and Wyoming has the least number of sales

# %%
#Visualize the sales by country
st.plot(kind='bar',figsize=(20,15))
plt.xlabel("Number of sales")
plt.ylabel("States")
plt.xticks()
plt.show()

# %%
data['State'].value_counts().mean()
# Out:
# 203.9591836734694

# %% [markdown]
# Average sales per state is approx 203

# %%
st[st<data['State'].value_counts().mean()]
# Out:
# Georgia                 184
# Tennessee               183
# Colorado                182
# Indiana                 149
# Kentucky                139
# Massachusetts           135
# New Jersey              130
# Oregon                  124
# Wisconsin               110
# Maryland                105
# Delaware                 96
# Minnesota                89
# Connecticut              82
# Missouri                 66
# Oklahoma                 66
# Alabama                  61
# Arkansas                 60
# Rhode Island             56
# Utah                     53
# Mississippi              53
# Louisiana                42
# South Carolina           42
# Nevada                   39
# Nebraska                 38
# New Mexico               37
# Iowa                     30
# New Hampshire            27
# Kansas                   24
# Idaho                    21
# Montana                  15
# South Dakota             12
# Vermont                  11
# District of Columbia     10
# ...

# %% [markdown]
# WE can see most of the states are not having having sales even less than average. They have to increase their promotion to attract customers and increase their sales

# %% [markdown]
# **Analyzing the sales city-wise**

# %%
cit = data['City'].value_counts()
cit
# Out:
# New York City     915
# Los Angeles       747
# Philadelphia      537
# San Francisco     510
# Seattle           428
#                  ...
# Baytown             1
# Citrus Heights      1
# Manhattan           1
# Murrieta            1
# Holyoke             1
# Name: City, Length: 531, dtype: int64

# %%
#WE can see that New York City having large number of sales. Let's visualize using plt.
cit.head(100).plot(kind='bar', figsize= (20,10), color= 'orange')
plt.xlabel("Cities")
plt.ylabel('Number of sales')
plt.show()

# %%
data['City'].value_counts().mean()
# Out:
# 18.821092278719398

# %%
cit[cit<data['City'].value_counts().mean()].value_counts()
# Out:
# 1     70
# 2     63
# 3     52
# 4     44
# 5     37
# 6     35
# 7     23
# 8     22
# 10    19
# 11    17
# 9     14
# 13    11
# 16    10
# 14     8
# 15     7
# 12     4
# 17     3
# 18     3
# Name: City, dtype: int64

# %% [markdown]
# There are 70 cities with number of sales equal to one only. They need to make strategies  for atracting the customers

# %% [markdown]
# Now visualize the distribution of different sub categories

# %%
plt.figure(figsize=(14,12))
sns.countplot(data['Sub-Category'])
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # We can see that "Binders" are having the most sales.
# ### Let us visualize the remaining column also.

# %%
plt.figure(figsize=(9,6))
plt.pie(data['Category'].value_counts(), labels=data['Category'].value_counts().index)
plt.title('Categories of Items for Sale')
plt.show()

# %%
sns.countplot(data['Segment'])
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(12,6))
plt.pie(data['Region'].value_counts(), labels=data['Region'].value_counts().index)
plt.title('Visualizing the given regions ')
plt.show()

# %% [markdown]
# **Change in profit wrt all features**

# %%
plt.figure(figsize=(14,8))
sns.barplot(x=data['Sub-Category'], y=data['Profit'])
plt.xticks()
plt.yticks()
plt.show()

# %% [markdown]
# We can see that the maximum profit is obtained by Copiers

# %% [markdown]
# **Change in Profit by region**

# %%
plt.figure(figsize=(14,8))
sns.barplot(x=data['Region'], y=data['Profit'])
plt.xticks()
plt.show()

# %% [markdown]
# We can see that the maximum profit is from the West Region of the US. To improve profit, increase the sales in Central Region of the US.

# %% [markdown]
# ## **Task Completed**
